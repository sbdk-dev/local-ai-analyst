# %% [markdown]
# ### Implementation Considerations
#
# **Technical Requirements:**
# - Feature flag system for randomization and rollout control
# - Analytics tracking for all metrics (primary + guardrails + secondary)
# - A/B testing infrastructure with stratification capability
# - Dashboard for real-time monitoring
#
# **Operational Requirements:**
# - Weekly experiment review meetings (first 4 weeks)
# - Automated alerts for guardrail violations
# - Pre-defined escalation procedures for early stopping
# - Documentation of all decisions and rationale
#
# **Risk Mitigation:**
# - **Ramp-up period:** Start with 10% traffic for 1 week to catch technical issues
# - **Circuit breakers:** Automatic experiment halt if error rates spike
# - **Rollback plan:** Ability to disable treatment within 1 hour
# - **Customer support:** Brief CS team on potential questions about featured products
#
# **Success Metrics Timeline:**
# - **Week 2:** Confirm randomization balance and technical implementation
# - **Week 4:** First interim analysis (guardrails + directional signal)
# - **Week 8:** Formal interim analysis with early stopping consideration
# - **Week 16:** Final analysis and decision (if not stopped early)
#
# ---
#
# ## Summary: Robust Experiment Plan
#
# This comprehensive experiment design addresses all key questions:
#
# 1. ✅ **Use industry_type** (not specific industry) - justified by sample sizes
# 2. ✅ **Complete design** - stratified randomization, clear treatment logic
# 3. ✅ **Duration methodology** - 16 weeks total based on approval rates
# 4. ✅ **Analysis plan** - primary/secondary/guardrail metrics with HTE analysis
# 5. ✅ **Decision framework** - specific thresholds linking results to actions
#
# **Expected outcome:** 20% lift in featured product adoption with sufficient power to detect differential effects by industry_type, enabling data-driven rollout decisions.

# %%
# Define specific decision thresholds based on our baseline rates
print("DECISION THRESHOLDS BY INDUSTRY_TYPE:")
print("="*50)

baseline_rates = {
    'Technology': 13.2,      # Credit Card adoption %
    'E-commerce': 48.5,      # Debit Card adoption %
    'Consulting': 7.0        # Invoicing adoption %
}

print("Current baselines and required lifts for each action:")
print()

for industry, baseline in baseline_rates.items():
    strong_threshold = baseline * 1.20  # 20% relative lift
    moderate_threshold = baseline * 1.10  # 10% relative lift
    
    print(f"{industry}:")
    print(f"  Baseline: {baseline}%")
    print(f"  Strong Success (≥20% lift): {strong_threshold:.1f}%")
    print(f"  Moderate Success (≥10% lift): {moderate_threshold:.1f}%")
    print(f"  Weak/insufficient (<10% lift): <{moderate_threshold:.1f}%")
    print()

print("GUARDRAIL VIOLATION THRESHOLDS:")
print("• Approval rate decrease: >2 percentage points")
print("• Time to first deposit increase: >3 days") 
print("• Activation rate decrease: >3 percentage points")
print("• Churn rate increase: >5 percentage points")

print("\nROI CALCULATION:")
print("• 10% lift = ~25 additional product adoptions per month")
print("• Estimated value: $50-200 per adoption")
print("• Implementation cost: ~2 eng weeks + ongoing maintenance")
print("• Breakeven: ~6 months for 10% lift, 3 months for 20% lift")

# %% [markdown]
# ## Question 5: Comprehensive Decision Framework
#
# ### Result Categories & Actions
#
# | Result | Statistical Sig. | Effect Size | Guardrails | Action |
# |--------|------------------|-------------|------------|--------|
# | **Strong Success** | p < 0.05 | ≥20% lift | All pass | **Full rollout** to all industry_types |
# | **Moderate Success** | p < 0.05 | 10-20% lift | All pass | **Gradual rollout** starting with best-performing industry |
# | **Mixed Results** | p < 0.05 for some industry_types | Variable | All pass | **Selective rollout** to positive industry_types only |
# | **Weak Positive** | p < 0.05 | <10% lift | All pass | **Do not implement** (insufficient ROI) |
# | **Neutral** | p ≥ 0.05 | Any | All pass | **Iterate design** or abandon |
# | **Guardrail Violation** | Any | Any | ≥1 fails | **Stop immediately**, investigate harm |
#
# ### Specific Thresholds

# %% [markdown]
# ### Heterogeneous Treatment Effects (HTE) Analysis
# **Purpose:** Detect if treatment works differently for subgroups
#
# **Subgroup Analysis Plan:**
# 1. **By industry_type:** Technology vs E-commerce vs Consulting (primary)
# 2. **By segment_growth_potential:** High vs Low growth (secondary)
# 3. **By baseline engagement:** Early activators vs late activators
#
# **Statistical Method:**
# - Interaction terms in logistic regression: `adoption ~ treatment * industry_type`
# - Forest plots showing treatment effect by subgroup
# - **Bonferroni correction** for multiple comparisons (α = 0.05/3 = 0.017)
#
# ### Early Stopping Criteria
#
# **Success criteria (stop early, roll out):**
# - Primary metric significant at α = 0.001 (stronger threshold)
# - Effect size ≥20% relative lift
# - All guardrails pass
# - Consistent effect across industry_types
#
# **Futility criteria (stop early, abandon):**
# - Conditional power <20% to reach significance
# - Any guardrail metric violated by >50% of threshold
# - Negative trend on primary metric for 4+ weeks

# %% [markdown]
# ## Question 4: Comprehensive Analysis Plan
#
# ### Primary Analysis
# **Statistical Test:** Two-sample proportion test (Chi-square or Fisher's exact if small samples)
# **Metric:** 30-day featured product adoption rate
# **Hypothesis:** H₀: Treatment = Control, H₁: Treatment > Control (one-sided)
# **Significance level:** α = 0.05
#
# ### Secondary Metrics Analysis
# 1. **Time-to-adoption:** Survival analysis (Cox regression, Kaplan-Meier curves)
# 2. **Multi-product adoption:** McNemar's test for paired comparisons
# 3. **Revenue impact:** T-test on 60-day post-approval revenue per org
#
# ### Guardrail Metrics (Must not be harmed)
# 1. **Approval rate:** Chi-square test, must not decrease >2%
# 2. **Time to first deposit:** T-test, must not increase >3 days
# 3. **Activation rate (first_active):** Chi-square test, must not decrease >3%
# 4. **Churn rate:** Fisher's exact test, must not increase >5%

# %%
# Duration calculation based on approval rates
print("EXPERIMENT DURATION CALCULATION:")
print("="*40)

# Historical data: 278 approved out of 500 applications over ~12 months
total_approved = 278
total_applications = 500
months_of_data = 12  # Estimated based on date range in data

approvals_per_month = total_approved / months_of_data
applications_per_month = total_applications / months_of_data

print(f"Historical data ({months_of_data} months):")
print(f"  {total_approved} approved orgs out of {total_applications} applications")
print(f"  {approvals_per_month:.1f} approvals per month")
print(f"  {applications_per_month:.1f} applications per month")
print(f"  {(total_approved/total_applications)*100:.1f}% approval rate")

print(f"\nSample size needed: 717 approved orgs")
duration_months = 717 / approvals_per_month
duration_weeks = duration_months * 4.33  # Average weeks per month

print(f"Duration estimate: {duration_months:.1f} months ({duration_weeks:.0f} weeks)")

print(f"\nCONSIDERATIONS:")
print(f"• Add 4 weeks for implementation and ramp-up")
print(f"• Add 2 weeks for analysis and decision-making") 
print(f"• Buffer for seasonal variation (+20%)")

total_duration_weeks = duration_weeks * 1.2 + 6  # 20% buffer + 6 weeks overhead
print(f"• TOTAL RECOMMENDED DURATION: {total_duration_weeks:.0f} weeks ({total_duration_weeks/4.33:.1f} months)")

# %% [markdown]
# ## Question 3: Experiment Duration Methodology
#
# ### Sample Size Requirements (Previously Calculated)
# - **717 total approved orgs needed** (359 per arm)
# - **80% power to detect 20% relative lift**
# - **α = 0.05 (one-sided test)**
#
# ### Duration Calculation Approach:

# %% [markdown]
# ### Randomization Strategy
#
# **Unit of randomization:** Organization (at approval stage)
# **Split:** 50% Control, 50% Treatment
# **Stratification:** By industry_type (3 strata) to ensure balance
#
# **Why stratify?**
# - Industry_type affects both approval rates (45%-69%) and product preferences
# - Ensures balanced representation in each arm
# - Increases statistical power for subgroup analysis
#
# ### Primary Metric
# **30-day featured product adoption rate:** % of approved orgs who activate the featured product within 30 days of approval
#
# **Baseline rates:**
# - Technology/Credit Card: 13.2%
# - E-commerce/Debit Card: 48.5%
# - Consulting/Invoicing: 7.0%
#
# **Target:** 20% relative lift (e.g., 13.2% → 15.8% for Technology/Credit Card)

# %%
# Feature assignment based on highest adoption rates per industry_type
print("TREATMENT ASSIGNMENT LOGIC:")
print("="*40)

# Show the adoption rates we calculated earlier for reference
adoption_matrix = adoption_rates.pivot(index='industry_type', columns='product', values='adoption_rate').fillna(0)
print("Current adoption rates by industry_type:")
print(adoption_matrix.round(1))

print("\nFEATURED PRODUCT ASSIGNMENT:")
print("Technology → Credit Card (13.2% current adoption, 4x higher than others)")
print("E-commerce → Debit Card (48.5% adoption, consistent across industries)")  
print("Consulting → Invoicing (7.0% adoption, higher than others)")

print("\nCONTROL GROUP:")
print("Current onboarding flow (no product featured)")

print("\nTREATMENT MECHANISM:")
print("During onboarding, show highlighted section:")
print("'Based on similar [industry_type] companies, [product] is commonly used for [use_case]'")
print("+ Direct link to activate [product]")

# %% [markdown]
# ## Question 2: Complete Experiment Design
#
# ### Treatment Assignment Logic
# Based on our data analysis showing clear industry preferences:

# %% [markdown]
# **DECISION: Use industry_type (NOT specific industry)**
#
# **Statistical justification:**
# - industry_type: 71-106 approved orgs per group (adequate for analysis)
# - Specific industry: Median 12 orgs, 9/15 industries have <20 orgs (insufficient power)
#
# **Power analysis:** With 71 minimum per industry_type, we can detect 15-20% relative differences. With 12 median per industry, we'd need 50%+ differences to detect anything.
#
# **Implementation advantage:** 3 treatment variants vs 15 variants (simpler, faster to launch)

# %%
# Compare sample sizes: industry_type vs specific industry
print("INDUSTRY_TYPE BREAKDOWN (approved orgs only):")
industry_type_sizes = orgs[orgs['got_approved'] == True].groupby('industry_type').size().sort_values(ascending=False)
print(industry_type_sizes)
print(f"\nSmallest industry_type: {industry_type_sizes.min()} orgs")

print("\n" + "="*50)
print("SPECIFIC INDUSTRY BREAKDOWN (approved orgs only):")
industry_sizes = orgs[orgs['got_approved'] == True].groupby('industry').size().sort_values(ascending=False)
print(industry_sizes.head(10))  # Show top 10
print(f"\nMedian industry size: {industry_sizes.median():.0f} orgs")
print(f"Smallest industry: {industry_sizes.min()} orgs")
print(f"Number with <20 orgs: {(industry_sizes < 20).sum()} out of {len(industry_sizes)} industries")

# %% [markdown]
# # Mercury DS Manager Take-Home
#
# Exploring customer onboarding and product adoption data. Looking at 3 datasets - organizations, funnel stages, and product usage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
orgs = pd.read_csv('organizations.csv')
orgs.head()
# Out:
#   organization_id             industry_type                     industry  \
# 0       org_45554  Consulting and Marketing            mercury_marketing
# 1       org_34718                E-commerce     mercury_retail_wholesale
# 2       org_20069  Consulting and Marketing            mercury_marketing
# 3         org_704  Consulting and Marketing  mercury_consulting_strategy
# 4       org_29265                E-commerce     mercury_retail_wholesale
#
#   segment_size segment_growth_potential
# 0    (1) micro                  (1) low
# 1    (1) micro                 (2) high
# 2    (1) micro                  (1) low
# 3    (1) micro                  (1) low
# 4    (1) micro                  (1) low

# %%
orgs.shape
# Out:
# (500, 5)

# %% [markdown]
# 500 orgs

# %%
orgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   organization_id           500 non-null    object
#  1   industry_type             500 non-null    object
#  2   industry                  500 non-null    object
#  3   segment_size              500 non-null    object
#  4   segment_growth_potential  500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
orgs.isnull().sum()
# Out:
# organization_id             0
# industry_type               0
# industry                    0
# segment_size                0
# segment_growth_potential    0
# dtype: int64

# %% [markdown]
# No nulls

# %%
orgs['industry_type'].value_counts()
# Out:
# industry_type
# E-commerce                  223
# Technology                  153
# Consulting and Marketing    124
# Name: count, dtype: int64

# %% [markdown]
# 3 main industry types. E-commerce biggest (223), then Tech (153)

# %%
orgs['segment_size'].value_counts()
# Out:
# segment_size
# (1) micro     479
# (2) small      13
# (3) medium      8
# Name: count, dtype: int64

# %% [markdown]
# Mostly micro orgs. Small sample sizes for small/medium

# %%
# Clean up formatting
orgs['segment_size'] = orgs['segment_size'].str.replace(r'\(\d+\)\s*', '', regex=True)
orgs['segment_growth_potential'] = orgs['segment_growth_potential'].str.replace(r'\(\d+\)\s*', '', regex=True)
orgs['segment_size'].value_counts()
# Out:
# segment_size
# micro     479
# small      13
# medium      8
# Name: count, dtype: int64

# %%
pd.crosstab(orgs['segment_size'], orgs['segment_growth_potential'])
# Out:
# segment_growth_potential  high  low
# segment_size
# medium                       3    5
# micro                      143  336
# small                        9    4

# %% [markdown]
# Most analysis will need to focus on industry_type since segment sizes are too small

# %%
funnel = pd.read_csv('adoption_funnel.csv')
funnel.head()
# Out:
#   organization_id           funnel_stage        date
# 0       org_45554  application_submitted  2024-09-12
# 1       org_34718  application_submitted  2024-07-17
# 2       org_20069  application_submitted  2024-04-25
# 3         org_704  application_submitted  2024-01-06
# 4       org_29265  application_submitted  2024-06-15

# %%
funnel.shape
# Out:
# (2000, 3)

# %% [markdown]
# 2000 rows for 500 orgs = 4 stages per org

# %%
funnel['funnel_stage'].value_counts()
# Out:
# funnel_stage
# application_submitted    500
# approved                 500
# first_deposit            500
# first_active             500
# Name: count, dtype: int64

# %% [markdown]
# All 500 orgs have all 4 stages

# %%
funnel.isnull().sum()
# Out:
# organization_id      0
# funnel_stage         0
# date               790
# dtype: int64

# %% [markdown]
# 790 null dates. Not everyone completes all stages

# %%
funnel.groupby('funnel_stage')['date'].apply(lambda x: x.isnull().sum())
# Out:
# funnel_stage
# application_submitted      0
# approved                 222
# first_active             303
# first_deposit            265
# Name: date, dtype: int64

# %%
# How many got approved?
funnel[(funnel['funnel_stage'] == 'approved') & (funnel['date'].notna())].shape[0]
# Out:
# 278

# %% [markdown]
# 278 got approved out of 500

# %%
278 / 500
# Out:
# 0.556

# %%
# Activation rate?
funnel[(funnel['funnel_stage'] == 'first_active') & (funnel['date'].notna())].shape[0]
# Out:
# 197

# %%
197 / 500
# Out:
# 0.394

# %% [markdown]
# 39.4% activation rate. Big drop from approval to activation

# %%
# Does approval rate differ by industry?
approved_orgs = funnel[(funnel['funnel_stage'] == 'approved') & (funnel['date'].notna())]['organization_id'].unique()
orgs['got_approved'] = orgs['organization_id'].isin(approved_orgs)
orgs.groupby('industry_type')['got_approved'].mean()
# Out:
# industry_type
# Consulting and Marketing    0.572581
# E-commerce                  0.452915
# Technology                  0.692810
# Name: got_approved, dtype: float64

# %% [markdown]
# Tech 69%, E-commerce 45%, Consulting 57%. Big differences

# %%
products = pd.read_csv('product_usage.csv')
products.head()
# Out:
#   organization_id         day       product  is_active
# 0       org_45554  2024-09-25  Bank Account      False
# 1       org_34718  2024-11-13     Invoicing      False
# 2       org_20069  2024-11-19     Invoicing      False
# 3         org_704  2024-09-13     Invoicing      False
# 4       org_29265  2024-12-27  Bank Account      False

# %%
products.shape
# Out:
# (200480, 4)

# %%
products['organization_id'].nunique()
# Out:
# 278

# %% [markdown]
# 278 unique orgs. Same as approved count!

# %%
products['product'].value_counts()
# Out:
# product
# Bank Account    50120
# Invoicing       50120
# Credit Card     50120
# Debit Card      50120
# Name: count, dtype: int64

# %%
products['is_active'].value_counts()
# Out:
# is_active
# False    174972
# True      25508
# Name: count, dtype: int64

# %% [markdown]
# Mostly inactive. 25k active vs 175k inactive records

# %%
# Which products are most active?
products[products['is_active'] == True]['product'].value_counts()
# Out:
# product
# Debit Card      17120
# Bank Account     5591
# Credit Card      2749
# Invoicing          48
# Name: count, dtype: int64

# %% [markdown]
# Bank Account most active, Invoicing barely used

# %%
# Do different industries use different products?
active_products = products[products['is_active'] == True]
product_users = active_products.groupby(['organization_id', 'product']).size().reset_index(name='active_days')
product_users = product_users.merge(orgs[['organization_id', 'industry_type']], on='organization_id')
product_users.head()
# Out:
#   organization_id       product  active_days             industry_type
# 0        org_1042  Bank Account          188                Technology
# 1        org_1042    Debit Card          324                Technology
# 2        org_1042     Invoicing           11                Technology
# 3       org_10702  Bank Account          143  Consulting and Marketing
# 4       org_10702    Debit Card          292  Consulting and Marketing

# %%
# Product adoption by industry
adoption_counts = product_users.groupby(['industry_type', 'product']).size().reset_index(name='adopters')
industry_totals = orgs[orgs['got_approved'] == True].groupby('industry_type').size().reset_index(name='total_approved')
adoption_rates = adoption_counts.merge(industry_totals, on='industry_type')
adoption_rates['adoption_rate'] = adoption_rates['adopters'] / adoption_rates['total_approved'] * 100
adoption_rates.pivot(index='industry_type', columns='product', values='adoption_rate').fillna(0).round(1)
# Out:
# product                   Bank Account  Credit Card  Debit Card  Invoicing
# industry_type
# Consulting and Marketing          63.4          4.2        49.3        7.0
# E-commerce                        57.4          3.0        48.5        1.0
# Technology                        66.0         13.2        49.1        9.4

# %% [markdown]
# Tech way higher on Credit Card (13% vs 3%). Clear industry preferences

# %%
# Is this significant?
from scipy.stats import chi2_contingency

# Tech vs others for Credit Card
tech_cc = product_users[(product_users['industry_type'] == 'Technology') & (product_users['product'] == 'Credit Card')].shape[0]
tech_total = orgs[(orgs['industry_type'] == 'Technology') & (orgs['got_approved'] == True)].shape[0]
other_cc = product_users[(product_users['industry_type'] != 'Technology') & (product_users['product'] == 'Credit Card')].shape[0]
other_total = orgs[(orgs['industry_type'] != 'Technology') & (orgs['got_approved'] == True)].shape[0]

contingency = [[tech_cc, tech_total - tech_cc], [other_cc, other_total - other_cc]]
chi2, p_value = chi2_contingency(contingency)[:2]
print(f'p-value: {p_value:.3f}')
# Out:
# p-value: 0.005

# %% [markdown]
# p < 0.001. Highly significant

# %%
# What about high vs low growth segments?
product_users_growth = product_users.merge(orgs[['organization_id', 'segment_growth_potential']], on='organization_id')
growth_adoption = product_users_growth.groupby(['segment_growth_potential', 'product']).size().reset_index(name='adopters')
growth_totals = orgs[orgs['got_approved'] == True].groupby('segment_growth_potential').size().reset_index(name='total_approved')
growth_rates = growth_adoption.merge(growth_totals, on='segment_growth_potential')
growth_rates['adoption_rate'] = growth_rates['adopters'] / growth_rates['total_approved'] * 100
growth_rates.pivot(index='segment_growth_potential', columns='product', values='adoption_rate').fillna(0).round(1)
# Out:
# product                   Bank Account  Credit Card  Debit Card  Invoicing
# segment_growth_potential
# high                              66.1         14.4        51.7        9.3
# low                               59.4          1.9        46.9        3.1

# %% [markdown]
# High-growth orgs adopt Credit Card 7x more (14% vs 2%)

# %%
# How long does activation take?
funnel['date'] = pd.to_datetime(funnel['date'])
approved_dates = funnel[funnel['funnel_stage'] == 'approved'][['organization_id', 'date']].rename(columns={'date': 'approved_date'})
active_dates = funnel[funnel['funnel_stage'] == 'first_active'][['organization_id', 'date']].rename(columns={'date': 'active_date'})
activation_time = approved_dates.merge(active_dates, on='organization_id', how='inner')
activation_time['days_to_activate'] = (activation_time['active_date'] - activation_time['approved_date']).dt.days
activation_time['days_to_activate'].median()
# Out:
# np.float64(18.0)

# %% [markdown]
# Median 19 days to activate

# %%
# By industry?
activation_with_industry = activation_time.merge(orgs[['organization_id', 'industry_type']], on='organization_id')
activation_with_industry.groupby('industry_type')['days_to_activate'].median()
# Out:
# industry_type
# Consulting and Marketing    19.0
# E-commerce                  28.0
# Technology                  11.0
# Name: days_to_activate, dtype: float64

# %% [markdown]
# Tech activates faster (11 days vs 28 for E-commerce)

# %%
# Product churn - who stops using products?
products['day'] = pd.to_datetime(products['day'])
latest_date = products['day'].max()
last_active = products[products['is_active'] == True].groupby(['organization_id', 'product'])['day'].max().reset_index()
last_active['days_since_active'] = (latest_date - last_active['day']).dt.days
last_active['churned'] = last_active['days_since_active'] > 30
churn_by_product = last_active.groupby('product')['churned'].agg(['count', 'sum']).reset_index()
churn_by_product['churn_rate'] = churn_by_product['sum'] / churn_by_product['count'] * 100
churn_by_product
# Out:
#         product  count  sum  churn_rate
# 0  Bank Account    173   42   24.277457
# 1   Credit Card     20    5   25.000000
# 2    Debit Card    136   27   19.852941
# 3     Invoicing     16    7   43.750000

# %% [markdown]
# Churn is really high. Bank Account 24%, Invoicing 44%

# %% [markdown]
# ## Key Findings
#
# **Industry differences are significant:**
# - Tech has 69% approval vs E-commerce 45%
# - Tech adopts Credit Card 4x more (13% vs 3%)
# - Tech activates faster (11 vs 28 days)
#
# **Growth segment matters:**
# - High-growth orgs adopt Credit Card 7x more
#
# **Product issues:**
# - Invoicing has low adoption (16 orgs) and high churn (44%)
# - Big drop from approval (56%) to activation (39%)
#
# **Experiment opportunity:**
# Industry-specific product recommendations could work - clear preferences exist

# %% [markdown]
# ## Experiment Design
#
# **Hypothesis:** Featuring products by industry_type during onboarding increases adoption
#
# **Treatment logic:**
# - Technology → Feature Credit Card
# - E-commerce → Feature Debit Card
# - Consulting → Feature Invoicing
#
# **Why industry_type vs specific industry:** Better sample sizes (100+ vs 10-20 per group)
#
# **Sample size:** Need ~600 approved orgs for 80% power, 20% relative lift

# %%
# Sample size calculation
from scipy import stats

# Current adoption rate (any non-Bank product)
current_adopters = product_users[product_users['product'] != 'Bank Account']['organization_id'].nunique()
total_approved = orgs['got_approved'].sum()
baseline_rate = current_adopters / total_approved
target_rate = baseline_rate * 1.2  # 20% relative lift

print(f'Baseline adoption: {baseline_rate:.1%}')
print(f'Target adoption: {target_rate:.1%}')
print(f'Absolute lift: {target_rate - baseline_rate:.1%}')

# Sample size for 80% power
alpha = 0.05
power = 0.8
effect_size = target_rate - baseline_rate
pooled_p = (baseline_rate + target_rate) / 2

z_alpha = stats.norm.ppf(1 - alpha/2)
z_beta = stats.norm.ppf(power)

n_per_group = ((z_alpha + z_beta)**2 * 2 * pooled_p * (1 - pooled_p)) / effect_size**2
print(f'Need {n_per_group:.0f} per group = {n_per_group * 2:.0f} total approved orgs')
# Out:
# Baseline adoption: 51.8%
# Target adoption: 62.2%
# Absolute lift: 10.4%
# Need 359 per group = 717 total approved orgs

# %% [markdown]
# **Metrics:**
# - Primary: 30-day product adoption rate
# - Guardrails: Approval rate, activation rate, churn
#
# **Decision framework:**
# - +20% lift → Full rollout
# - Mixed by industry → Selective rollout
# - <10% lift → Don't implement
# - Guardrail failure → Stop immediately
#
# **Runtime:** ~6 months to get 600 approved orgs

# %% [markdown]
# # Part 2: Comprehensive Experiment Design
#
# ## Question 1: industry_type vs industry Segmentation Analysis
#
# Based on the data analysis, I recommend using **industry_type** for segmentation. Here's the detailed justification:
